# %% [markdown]
# # Estruturas de decisão
#
# <span style="color: red;"><b>Todos os exercícios são feitos partindo-se do pressuposto de que todas as entradas são dadas de forma correta. Casos limite não mencionados no enunciado não são abordados porque não fazem parte do exercício.</b></span>

# %% [markdown]
# #### 1. Faça um Programa que peça dois números e imprima o maior deles.

# %%
num1 = int(input("Digite o primeiro número: "))
num2 = int(input("Digite o segundo número: "))

if num1 > num2:
    print("O maior número é: {}".format(num1))
else:
    print("O maior número é: {}".format(num2))
# Out:
# O maior número é: 1

# %% [markdown]
# #### 2. Faça um Programa que peça um valor e mostre na tela se o valor é positivo ou negativo.

# %%
valor = int(input("Di8gite um número inteiro: "))

if valor % 2 == 0:
    print("o número {} é par".format(valor))
else:
    print("o número {} é impar".format(valor))
# Out:
# o número 24 é par

# %% [markdown]
# #### 3. Faça um Programa que verifique o estado civil de uma pessoa. Se a letra digitada é "C" (Casado), "S" (Solteiro), "D" (Divorciado), "V" (Viúvo) ou "O" (outros). Conforme a letra escrita pelo usuário seu programa deve escrever o estado civil, exemplo:
#
# Usuário digita: C
#
# Seu programa deve responder:
# C - Casado

# %%
estado_civil = input("Digite o seu estado civil, C (casado), S (solteiro), D (divorciado), V (viúvo), O (outros): ")

if estado_civil == "C":
    print("Você é casado!")
elif estado_civil == "S":
    print("Você é solteiro!")
elif estado_civil == "D":
    print("Você é divorciado!")
elif estado_civil == "V":
    print("Você é viúvo!")
elif estado_civil == "O":
    print("Estado civil não identificado!")
else:
    if estado_civil != "C" or estado_civil != "S" or estado_civil != "D" or estado_civil != "V":
        print("Estado civil não identificado!")
# Out:
# Você é divorciado!

# %% [markdown]
# #### 4. Faça um Programa que verifique se o e-mail digitado faz parte dos e-mails de spam.

# %%
import re
emails_spam = "fulano@gmail.com,beltrano@gmail.com,ciclano@gmail.com"

email_digitado = input("Digite seu e-mail: ")

# Define a expressão regular para validar o formato do e-mail
regex_email = r'^[\w\.-]+@[\w\.-]+\.\w+$'

if re.match(regex_email, email_digitado):

    if email_digitado in emails_spam:
        print("O e-mail {} está cadastrado na lista de spam!!".format(email_digitado))
    else:
        print("O e-mail digitado foi: {}".format(email_digitado))
else:
    print("O e-mail digitado não é válido!!")
# Out:
# O e-mail digitado não é válido!!

# %% [markdown]
# #### 5. Faça um programa para a leitura de duas notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e apresentar:
#
# ##### A mensagem "Aprovado", se a média alcançada for maior ou igual a sete;
# ##### A mensagem "Reprovado", se a média for menor do que sete;
# ##### A mensagem "Aprovado com Distinção", se a média for igual a dez.

# %% [markdown]
# nota1 = float(input("Digite a primeira nota: "))
# nota2 = float(input("Digite a segunda nota: "))
# media = (nota1 + nota2) / 2
#
# if media >= 7:
#     print("")

# %%
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
media = (nota1 + nota2) / 2

if media >= 7:
    print("A sua média foi: {}. Você foi APROVADO!".format(media))
elif media == 10:
    print("A sua média foi: {}. Você foi APROVADO com distinção!".format(media))
else:
    print("A sua média foi: {}. Você foi REPROVADO!".format(media))
# Out:
# A sua média foi: 8.5. Você foi APROVADO!

# %% [markdown]
# #### 6. Faça um Programa que leia o orçamento de 3 empresas e mostre o maior deles.

# %%
orcamento1 = 1500
orcamento2 = 800
orcamento3 = 2000

if orcamento1 > orcamento2 and orcamento1 > orcamento3:
    print("O maior orçamento é: {}".format(orcamento1))
elif orcamento2 > orcamento1 and orcamento2 > orcamento3:
    print("O maior orçamento é: {}".format(orcamento2))
else:
    print("O maior orçamento é: {}".format(orcamento3))
# Out:
# O maior orçamento é: 2000

# %% [markdown]
# #### 7. Faça um Programa que leia três orçamentos e mostre o maior e o menor deles.

# %%
mais_barato = min(orcamento1, orcamento2, orcamento3)
mais_caro = max(orcamento1, orcamento2, orcamento3)

if orcamento1 == mais_barato:
    print("O {} é mais barato!".format(mais_barato))
elif orcamento2 == mais_barato:
    print("O {} é mais barato!".format(mais_barato))
else:
    print("O {} é mais barato!".format(mais_barato))

if orcamento1 == mais_caro:
    print("O {} é mais caro!".format(mais_caro))
elif orcamento2 == mais_caro:
    print("O {} é mais caro!".format(mais_caro))
else:
    print("O {} é mais caro!".format(mais_caro))
# Out:
# O 800 é mais barato!
# O 2000 é mais caro!

# %% [markdown]
# #### 8. Faça um programa que pergunte o preço de três produtos e informe qual produto você deve comprar, sabendo que a decisão é sempre pelo mais barato.

# %%
produto1 = float(input("Digite o preço do primeiro produto: "))
produto2 = float(input("Digite o preço do segundo produto "))
produto3 = float(input("Digite o preço do terceiro produto "))

menor_preco = min(produto1, produto2, produto3)

print("Valor do produto 1: {:.2f}".format(produto1))
print("Valor do produto 2: {:.2f}".format(produto2))
print("Valor do produto 3: {:.2f}".format(produto3))
    
if produto1 == menor_preco:
    print("Você deve comprar o produto1, pois ele tem o menor preço.")
elif produto2 == menor_preco:
    print("Você deve comprar o produto2, pois ele tem o menor preço.")
else:
    print("Você deve comprar o produto3, pois ele tem o menor preço.")
# Out:
# Valor do produto 1: 100.00
# Valor do produto 2: 40.00
# Valor do produto 3: 25.00
# Você deve comprar o produto3, pois ele tem o menor preço.

# %% [markdown]
# #### 9. Faça um Programa que leia três números e mostre-os em ordem decrescente.

# %%
num1 = int(input("Digite o primeiro número inteiro: "))
num2 = int(input("Digite o segundo número inteiro: "))
num3 = int(input("Digite o terceiro número inteiro: "))

numeros = [num1, num2, num3]

numeros.sort(reverse=True)

print("Os números digitados foram: ")

for numero in numeros:
    print(numero)
# Out:
# Os números digitados foram:
# 30
# 20
# 10

# %% [markdown]
# #### 10. Faça um Programa que pergunte em que turno você estuda. Peça para digitar M-matutino ou V-Vespertino ou N- Noturno. Imprima a mensagem "Bom Dia!", "Boa Tarde!" ou "Boa Noite!" ou "Valor Inválido!", conforme o caso.

# %%
periodo = input("Digite o período em que você estuda. M-matutino, V-vespertino ou N-noturno: ")
if periodo == "M":
    print("Bom dia!")
elif periodo == "V":
    print("Boa tarde!")

elif periodo == "N":
    print("Boa noite!")

else:
    print("Valor inválido")
# Out:
# Boa noite!

# %% [markdown]
# #### 11. As Organizações Tabajara resolveram dar um aumento de salário aos seus colaboradores e lhe contraram para desenvolver o programa que calculará os reajustes. Faça um programa que recebe o salário de um colaborador e o reajuste segundo o seguinte critério, baseado no salário atual:
#
# ##### salários até R\\$ 280,00 (incluindo) : aumento de 20%
#
# ##### salários entre R\\$ 280,00 e R\\$ 700,00 : aumento de 15%
#
# ##### salários entre R\\$ 700,00 e R\\$ 1500,00 : aumento de 10%
#
# ##### salários de R\\$ 1500,00 em diante : aumento de 5% Após o aumento ser realizado, informe na tela:
#
# ###### o salário antes do reajuste;
#
# ###### o percentual de aumento aplicado;
#
# ###### o valor do aumento;
#
# ###### o novo salário, após o aumento.
#
# ###### Obs: Não vamos nos preocupar tanto com a formatação dos números (nº de casas decimais, por exemplo, veremos isso no próximo módulo)

# %%
salario_antes_reajuste = float(input("Digite o seu salário atual:"))


if salario_antes_reajuste <= 280:
    valor_aumento = salario_antes_reajuste * 0.2
    salario_apos_reajuste = salario_antes_reajuste + valor_aumento
    print("O seu salário antes do reajuste: {:.2f}".format(salario_antes_reajuste))
    print("Percentual de aumento aplicado: 20%")
    print("Valor do aumento: {:.2f}".format(valor_aumento))
    print("Salário reajustado para {:.2f}".format(salario_apos_reajuste))

elif salario_antes_reajuste > 280 and salario_antes_reajuste <= 700:
    valor_aumento = salario_antes_reajuste * 0.15
    salario_apos_reajuste = salario_antes_reajuste + valor_aumento
    print("O seu salário antes do reajuste: {:.2f}".format(salario_antes_reajuste))
    print("Percentual de aumento aplicado: 15%")
    print("Valor do aumento: {:.2f}".format(valor_aumento))
    print("Salário reajustado para {:.2f}".format(salario_apos_reajuste))
elif salario_antes_reajuste > 700 and salario_antes_reajuste <= 1500:
    valor_aumento = salario_antes_reajuste * 0.1
    salario_apos_reajuste = salario_antes_reajuste + valor_aumento
    print("O seu salário antes do reajuste: {:.2f}".format(salario_antes_reajuste))
    print("Percentual de aumento aplicado: 10%")
    print("Valor do aumento: {:.2f}".format(valor_aumento))
    print("Salário reajustado para {:.2f}".format(salario_apos_reajuste))
else:
    valor_aumento = salario_antes_reajuste * 0.5
    salario_apos_reajuste = salario_antes_reajuste + valor_aumento
    print("O seu salário antes do reajuste: {:.2f}".format(salario_antes_reajuste))
    print("Percentual de aumento aplicado: 5%")
    print("Valor do aumento: {:.2f}".format(valor_aumento))
    print("Salário reajustado para {:.2f}".format(salario_apos_reajuste))
# Out:
# O seu salário antes do reajuste: 1501.00
# Percentual de aumento aplicado: 5%
# Valor do aumento: 750.50
# Salário reajustado para 2251.50

# %% [markdown]
# #### 12 . Faça um programa para o cálculo de uma folha de pagamento, sabendo que os descontos são do Imposto de Renda, que depende do salário bruto (conforme tabela abaixo) e que o FGTS corresponde a 11% do Salário Bruto, mas não é descontado (é a empresa que deposita). O Salário Líquido corresponde ao Salário Bruto menos os descontos. O programa deverá pedir ao usuário o valor da sua hora e a quantidade de horas trabalhadas no mês.
#
# Desconto do IR:<br>
# Salário Bruto até 900 (inclusive) - isento<br>
# Salário Bruto até 1500 (inclusive) - desconto de 5%<br>
# Salário Bruto até 2500 (inclusive) - desconto de 10%<br>
# Salário Bruto acima de 2500 - desconto de 20%<br>
# Imprima na tela as informações, dispostas conforme o exemplo abaixo. No exemplo o valor da hora é 5 e a quantidade de hora é 220.
#
# Salário Bruto: (5 * 220)        : R\\$ 1100,00<br>
# (-) IR (5%)                     : R\\$   55,00<br>
# (-) INSS ( 10%)                 : R\\$  110,00<br>
# FGTS (11%)                      : R\\$  121,00<br>
# Total de descontos              : R\\$  165,00<br>
# Salário Liquido                 : R\\$  935,00<br>
#
# ###### Obs: Não vamos nos preocupar tanto com a formatação dos números (nº de casas decimais, por exemplo, veremos isso no próximo módulo)

# %%
valor_hora = float(input("Digite o valor da sua hora trabalhada: "))
horas_trabalhadas = int(input("Digite a quantidade de horas trabalhadas: "))
salario_bruto = valor_hora * horas_trabalhadas
inss = salario_bruto * 0.1
fgts = salario_bruto * 0.11

if salario_bruto <= 900:
    imposto_renda = 0
    print("Salário Bruto: ({:.0f} * {:.2f}) = {:.2f}".format(valor_hora, horas_trabalhadas, salario_bruto))
    print("Sem Imposto de Renda!!!")
    print("INSS (10%): {:.2f}".format(inss))
    print("FGTS (11%): {:.2f}".format(fgts))
    total_descontos = inss + imposto_renda
    print("Total de descontos: {:.2f}".format(total_descontos))
    salario_liquido = salario_bruto - total_descontos
    print("Salário líquido: {:.2f}".format(salario_liquido))

elif salario_bruto > 900 and salario_bruto <= 1500:
    imposto_renda = salario_bruto * 0.05
    print("Salário Bruto: ({:.0f} * {:.2f}) = {:.2f}".format(valor_hora, horas_trabalhadas, salario_bruto))
    print("Imposto de Renda (5%): {:.2f}".format(imposto_renda))
    print("INSS (10%): {:.2f}".format(inss))
    print("FGTS (11%): {:.2f}".format(fgts))
    total_descontos = inss + imposto_renda
    print("Total de descontos: {:.2f}".format(total_descontos))
    salario_liquido = salario_bruto - total_descontos
    print("Salário líquido: {:.2f}".format(salario_liquido))

elif salario_bruto > 1500 and salario_bruto <= 2500:
    imposto_renda = salario_bruto * 0.1
    print("Salário Bruto: ({:.0f} * {:.2f}) = {:.2f}".format(valor_hora, horas_trabalhadas, salario_bruto))
    print("Imposto de Renda (10%): {:.2f}".format(imposto_renda))
    print("INSS (10%): {:.2f}".format(inss))
    print("FGTS (11%): {:.2f}".format(fgts))
    total_descontos = inss + imposto_renda
    print("Total de descontos: {:.2f}".format(total_descontos))
    salario_liquido = salario_bruto - total_descontos
    print("Salário líquido: {:.2f}".format(salario_liquido))

else:
    # salario_bruto > 2500:
    imposto_renda = salario_bruto * 0.2
    print("Salário Bruto: ({:.0f} * {:.2f}) = {:.2f}".format(valor_hora, horas_trabalhadas, salario_bruto))
    print("Imposto de Renda (20%): {:.2f}".format(imposto_renda))
    print("INSS (10%): {:.2f}".format(inss))
    print("FGTS (11%): {:.2f}".format(fgts))
    total_descontos = inss + imposto_renda
    print("Total de descontos: {:.2f}".format(total_descontos))
    salario_liquido = salario_bruto - total_descontos
    print("Salário líquido: {:.2f}".format(salario_liquido))
# Out:
# Salário Bruto: (40 * 300.00) = 12000.00
# Imposto de Renda (20%): 2400.00
# INSS (10%): 1200.00
# FGTS (11%): 1320.00
# Total de descontos: 3600.00
# Salário líquido: 8400.00

# %% [markdown]
# #### 13. Faça um Programa que leia um número e exiba o dia correspondente da semana. (1-Domingo, 2- Segunda, etc.), se digitar outro valor deve aparecer valor inválido.

# %%
dia = 7

if dia == 1:
    print("1 - Domingo")
elif dia == 2:
    print("2 - Segunda")
elif dia == 3:
    print("3 - Terça")
elif dia == 4:
    print("4 - Quarta")
elif dia == 5:
    print("5 - Quinta")
elif dia == 6:
    print("6 - Sexta")
elif dia == 7:
    print("7 - Sabado")
else:
    print("Digite um número de 1 a 7!")
# Out:
# 7 - Sabado

# %% [markdown]
# #### 14. Faça um programa que lê as duas notas parciais obtidas por um aluno numa disciplina ao longo de um semestre, e calcule a sua média. Em seguida, mostre qual conceito o aluno teve. A atribuição de conceitos obedece à tabela abaixo:
# <pre>
# Média de Aproveitamento  Conceito
# Entre 9.0 e 10.0        A
# Entre 7.5 e 9.0         B
# Entre 6.0 e 7.5         C
# Entre 4.0 e 6.0         D
# Entre 4.0 e zero        E
# </pre>

# %%
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
media = (nota1 + nota2) / 2

if media >= 9 and media <= 10:
    print("Você teve {} de média. Seu conceito é A".format(media))
elif media >= 7.5 and media < 9:
    print("Você teve {} de média. Seu conceito é B".format(media))
elif media >= 6 and media < 7.5:
    print("Você teve {} de média. Seu conceito é C".format(media))
elif media >= 4 and media < 6:
    print("Você teve {} de média. Seu conceito é D".format(media))
else:
    print("Você teve {} de média. Seu conceito é E".format(media))
# Out:
# Você teve 9.25 de média. Seu conceito é A

# %% [markdown]
# #### 15. Você está construindo um calendário para controlar dias de trabalho a pedido do RH. Nessa construção, você vai precisar definir quais anos são bissextos e quais não são, para montar o calendário de forma correta. Faça um Programa que peça um número correspondente a um determinado ano e em seguida informe se este ano é ou não bissexto.
# <pre>
# Dica para determinar se um ano é bissexto:
# - São bissextos todos os anos múltiplos de 400, p.ex.: 1600, 2000, 2400, 2800...
# - São bissextos todos os múltiplos de 4, exceto se for múltiplo de 100 mas não de 400,
# p.ex.: 1996, 2000, 2004, 2008, 2012, 2016, 2020, 2024, 2028...
# - Não são bissextos todos os demais anos.<br>
# ex1: 2004 é múltiplo de 4, mas não é múltiplo de 100, então é bissexto.
# ex2: 2000 é múltiplo de 4, mas é múltiplo de 100, só que também é multiplo de 400, então é bissexto (porque todo ano múltiplo de 400 é bissexto, independente do resto).
# ex3: 1900 é múltiplo de 4, é múltiplo de 100, mas não é múltiplo de 400, então não é bissexto
#
# </pre>
#
# Dica: lembre que: numero % 4 é o resto da divisão do número por 4, ex: 10 % 3 = 1 (já que 10/3 = 3 e resta 1)

# %%
ano_digitado = int(input("Digite o ano: "))

if ano_digitado % 400 == 0:
    print("O ano {} é bissexto".format(ano_digitado))
elif ano_digitado % 4 == 0 and ano_digitado % 100 == 0 and ano_digitado % 400 != 0:
    print("O ano {} não é bissexto".format(ano_digitado))
elif ano_digitado % 4 == 0 and ano_digitado % 100 == 0 and ano_digitado % 400 == 0:
    print("O ano {} é bissexto".format(ano_digitado))
elif ano_digitado % 4 == 0:
    print("O ano {} é bissexto".format(ano_digitado))
else:
    print("O ano {} não é bissexto".format(ano_digitado))
# Out:
# O ano 1980 é bissexto

# %% [markdown]
# #### 16. Faça um Programa para leitura de três notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e presentar:
# <pre>
# A mensagem "Aprovado", se a média for maior ou igual a 7, com a respectiva média alcançada;
# A mensagem "Reprovado", se a média for menor do que 7, com a respectiva média alcançada;
# A mensagem "Aprovado com Distinção", se a média for igual a 10.
# </pre>

# %%
nota1 = input("Digite a primeira nota: ")
nota2 = input("Digite a segunda nota: ")
nota3 = input("Digite a terceira nota: ")

if nota1 == '' or nota2 == '' or nota3 == '':
    print("Digite uma nota válida!")
else:
    nota1 = float(nota1)
    nota2 = float(nota2)
    nota3 = float(nota3)

    
# Calculando a média

    media = (nota1 + nota2 + nota3) / 3

    if media >= 7 and media < 10:
        print("Média: {:.1f} - APROVADO".format(media))
    elif media < 7:
        print("Média: {:.1f} - REPROVADO".format(media))
    elif media == 10:
        print("Média: {:.1f} - APROVADO COM DISTINÇÃO".format(media))
    else:
        print("Digite uma nota válida!")
# Out:
# Média: 9.8 - APROVADO

# %% [markdown]
# #### 17. João Papo-de-Pescador, homem de bem, comprou um microcomputador para controlar o rendimento diário de seu trabalho. Toda vez que ele traz um peso de peixes maior que o estabelecido pelo regulamento de pesca do estado de São Paulo (50 quilos) deve pagar uma multa de R$ 4,00 por quilo excedente. João precisa que você faça um programa que leia a variável peso (peso de peixes) e calcule o excesso. Gravar na variável excesso a quantidade de quilos além do limite e na variável multa o valor da multa que João deverá pagar. Imprima os dados do programa com as mensagens adequadas.

# %%
peso_permitido = 50
pesca = float(input("Digite a quantidade de peixe em Kg: "))

if pesca > peso_permitido:
    excedente = pesca - peso_permitido
    multa = excedente * 4
    print("Você excedeu o limite de peso permitido em {:.0f}kg! O valor da multa é de {:.2f} ".format(excedente, multa))
else:
    print("Você não excedeu o limite de peso permitido!")
# Out:
# Você excedeu o limite de peso permitido em 20kg! O valor da multa é de 80.00

# %% [markdown]
# #### 18. Faça um Programa para um caixa eletrônico. O programa deverá perguntar ao usuário a valor do saque e depois informar quantas notas de cada valor serão fornecidas. As notas disponíveis serão as de 1, 5, 10, 50 e 100 reais. O valor mínimo é de 10 reais e o máximo de 600 reais. O programa não deve se preocupar com a quantidade de notas existentes na máquina.
# <pre>
# Exemplo 1: Para sacar a quantia de 256 reais, o programa fornece duas notas de 100, uma nota de 50, uma nota de 5 e uma nota de 1;
# Exemplo 2: Para sacar a quantia de 399 reais, o programa fornece três notas de 100, uma nota de 50, quatro notas de 10, uma nota de 5 e quatro notas de 1.
# </pre>
#
# Dica1: numero // 10 vai te dar como resposta a parte inteira da divisão do número por 10.<br>
# Dica2: numero % 10 vai te dar o resto da divisão do número por 10.

# %%
saque = int(input("Digite o valor do saque: "))

n100 = 0
n50 = 0
n10 = 0
n5 = 0
n1 = 0

if 10 <= saque <= 600:  # verifica se valor está no intervalo de 10 e 600
    print("são necessárias: ")
    if saque >= 100:
        n100 = saque // 100
        print(n100, 'notas de 100')
    if saque % 100 >= 50:
        n50 = (saque - 100*n100) // 50
        print(n50, 'notas de 50')
    if saque % 50 >= 10:
        n10 = (saque - 100*n100 - 50*n50) // 10
        print(n10, 'notas de 10')
    if saque % 10 >= 5:
        n5 = (saque - 100*n100 - 50*n50 - 10*n10) // 5
        print(n5, 'notas de 5')
    if saque % 5 >= 1:
        n1 = (saque - 100*n100 - 50*n50 - 10*n10 - 5*n5) // 1
        print(n1, 'notas de 1')
else:
    print('Informe um valor entr 10 e 600 reais!')
# Out:
# são necessárias:
# 5 notas de 100
# 1 notas de 50
# 4 notas de 10

# %% [markdown]
# #### 19. Faça um programa que faça 5 perguntas para uma pessoa sobre um crime. As perguntas são:
# <pre>
# "Telefonou para a vítima?"
# "Esteve no local do crime?"
# "Mora perto da vítima?"
# "Devia para a vítima?"
# "Já trabalhou com a vítima?"
# O programa deve no final emitir uma classificação sobre a participação da pessoa no crime. Se a pessoa responder positivamente a 2 questões ela deve ser classificada como "Suspeita", entre 3 e 4 como "Cúmplice" e 5 como "Assassino". Caso contrário, ele será classificado como "Inocente".
# </pre>

# %%
p1 = input("Telefonou para a vítima? (S/N): ")
p2 = input("Esteve no local do crime? (S/N): ")
p3 = input("Mora perto da vítima? (S/N): ")
p4 = input("Devia para a vítima? (S/N): ")
p5 = input("Já trabalhou com a vítima? (S/N): ")

contador = 0

if p1.upper() == "S":
    contador = contador + 1
if p2.upper() == "S":
    contador = contador + 1
if p3.upper() == "S":
    contador = contador + 1
if p4.upper() == "S":
    contador = contador + 1
if p5.upper() == "S":
    contador = contador + 1


if contador == 5:
    print("Você é o assassino!")
elif 3 <= contador <= 4:
    print("Você é cúmplice")
elif contador == 2:
    print("Voce é suspeito(a)!")
else:
    print("Você está liberado(a).")
# Out:
# Você está liberado(a).

# %% [markdown]
# #### 20. Um posto está vendendo combustíveis com a seguinte tabela de descontos:
# <pre>
# Álcool:
# até 20 litros, desconto de 3% por litro
# acima de 20 litros, desconto de 5% por litro
# Gasolina:
# até 20 litros, desconto de 4% por litro
# acima de 20 litros, desconto de 6% por litro
#
# Escreva um algoritmo que leia o número de litros vendidos, o tipo de combustível (codificado da seguinte forma: A-álcool, G-gasolina), calcule e imprima o valor a ser pago pelo cliente sabendo-se que o preço do litro da gasolina é R$ 2,50 o preço do litro do álcool é R$ 1,90.
# </pre>

# %%
combustivel = input("Escolha A para alcool ou G para gasolina: ").upper()
qtde_str = input("Qual a quantidade de combustível: ")

if combustivel == 'A' or combustivel == 'G' and qtde_str != '':

    qtde = int(qtde_str)

    if combustivel == 'A' and qtde <= 20:
        valor = 4 * qtde
        pgto = (4 * qtde) * 0.97
        desconto = '3 %'
    if combustivel == 'A' and qtde > 20:
        valor = 4 * qtde
        pgto = (4 * qtde) * 0.95
        desconto = '5%'
    if combustivel  == 'G' and qtde <= 20:
        valor = 5 * qtde
        pgto = (5 * qtde) * 0.96
        desconto = '4 %'
    if combustivel == 'G' and qtde > 20:
        valor = 5 * qtde
        pgto = (5 * qtde) * 0.94
        desconto = '6 %'

    if combustivel  == 'A':
        combustivel = 'alcool'
    else:
        combustivel = 'gasolina'    


    print("abastecimento com:", combustivel)
    print("Quantidade:", qtde, "litros")
    print("O valor a ser pago por {:.0f} litros de {} com {} de desconto é: {:.2f}".format(qtde, combustivel, desconto, pgto))
    print("Desconto de {:.2f}".format(valor - pgto))
else:
    print("Voce precisa informar qual o combustível (A-alcool ou G-gasolina) e a quantidade!")
# Out:
# Voce precisa informar qual o combustível (A-alcool ou G-gasolina) e a quantidade!

# %% [markdown]
# #### 21. Uma fruteira está vendendo frutas com a seguinte tabela de preços:
# <pre>
#                       Até 5 Kg           Acima de 5 Kg
# Morango         R$ 2,50 por Kg          R$ 2,20 por Kg
# Maçã            R$ 1,80 por Kg          R$ 1,50 por Kg
# Se o cliente comprar mais de 8 Kg em frutas ou o valor total da compra ultrapassar R$ 25,00, receberá ainda um desconto de 10% sobre este total. Escreva um algoritmo para ler a quantidade (em Kg) de morangos e a quantidade (em Kg) de maças adquiridas e escreva o valor a ser pago pelo cliente.
# </pre>

# %%
qtde_morango = input("Digite a quantidade de morangos (em kg): ")
qtde_maca = input("Digite a quantidade de maçãs (em kg): ")

if qtde_morango.isnumeric() and qtde_maca.isnumeric():
    qtde_morango = float(qtde_morango)
    qtde_maca = float(qtde_maca)

    preco_morango = 2.50 if qtde_morango <= 5 else 2.20
    preco_maca = 1.80 if qtde_maca <= 5 else 1.50

    total = qtde_morango * preco_morango + qtde_maca * preco_maca
    print(f'Valor total da compra: {total:.2f}')

    if qtde_morango + qtde_maca > 8 or total > 25:
        desconto = total * 0.1  # Cálculo do Desconto
        total -= desconto  # Aplicação do Desconto ao Total (total = total - desconto)
        valor_desconto = round(desconto, 2)  # Arredondamento do Desconto

        desconto = "10%"
    else:
        valor_desconto = 0
        desconto = "0%"

    print(f"Morangos: {qtde_morango} Kg | Valor = R$ {qtde_morango * preco_morango:.2f}")
    print(f"Maçãs: {qtde_maca} Kg | Valor = R$ {qtde_maca * preco_maca:.2f}")
    print(f"Peso total = {qtde_morango + qtde_maca} Kg")
    print(f'desconto de {valor_desconto:.2f} ({desconto})')
    print(f"Total a ser pago: R$ {total:.2f}")
else:
    print("Digite um valor válido!")
# Out:
# Valor total da compra: 22.20
# Morangos: 6.0 Kg | Valor = R$ 13.20
# Maçãs: 6.0 Kg | Valor = R$ 9.00
# Peso total = 12.0 Kg
# desconto de 2.22 (10%)
# Total a ser pago: R$ 19.98

# %% [markdown]
# #### 22. O Hipermercado Tabajara está com uma promoção de carnes que é imperdível. Confira:
# <pre>
#                       Até 5 Kg           Acima de 5 Kg
# File Duplo      R$ 4,90 por Kg          R$ 5,80 por Kg
# Alcatra         R$ 5,90 por Kg          R$ 6,80 por Kg
# Picanha         R$ 6,90 por Kg          R$ 7,80 por Kg
# Para atender a todos os clientes, cada cliente poderá levar apenas um dos tipos de carne da promoção, porém não há limites para a quantidade de carne por cliente. Se compra for feita no cartão Tabajara o cliente receberá ainda um desconto de 5% sobre o total da compra. Escreva um programa que peça o tipo e a quantidade de carne comprada pelo usuário e gere um cupom fiscal, contendo as informações da compra: tipo e quantidade de carne, preço total, tipo de pagamento, valor do desconto e valor a pagar.
# </pre>

# %%
cesta_tipo = input("Escolha a carne: File Duplo, Alcatra ou Picanha: ")
cesta_qtde = input("Digite a quantidade em Kg: ")
pgto_tipo = input("Escolha a forma de pagto: C-Cartão Tabajara, D-Dinheiro")

if cesta_tipo == "File Duplo" or cesta_tipo == "Alcatra" or cesta_tipo == "Picanha" and cesta_qtde.isnumeric():
   
    cesta_qtde = int(cesta_qtde)

    if cesta_tipo == "File Duplo" and cesta_qtde > 5:
        total = cesta_qtde * 5.80
    elif cesta_tipo == "File Duplo" and cesta_qtde <= 5:
        total = cesta_qtde * 4.90
    elif cesta_tipo == "Alcatra" and cesta_qtde > 5:
        total = cesta_qtde * 6.80
    elif cesta_tipo == "Alcatra" and cesta_qtde <= 5:
        total = cesta_qtde * 5.90
    elif cesta_tipo == "Picanha" and cesta_qtde > 5:
        total = cesta_qtde * 7.80
    elif cesta_tipo == "Picanha" and cesta_qtde <= 5:
        total = cesta_qtde * 6.90

    print("############# CUPOM FISCAL #############")
    print(f'### Tipo da carne ---------- {cesta_tipo}')
    print("### Quantidade --------------- {:.0f} Kg".format(cesta_qtde))
    print("### Preço total ----------- R$ {:.2f}".format(total))

    desconto = 0.05 * total if pgto_tipo == "C" else 0

    if desconto:
        pgto_tipo = "C. Tabajara"
    else:
        pgto_tipo = "Dinheiro"

    print(f'### Forma de pgto ------ {pgto_tipo}')

    print("### Desconto --------------- R$ {:.2f}".format(desconto))
    print("### Valor a pagar --------- R$ {:.2f}".format(total - desconto))
else:
    print("Preencha corretamente!")
# Out:
# Preencha corretamente!

# %% [markdown]
# #### 23. Faça um Programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 6 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\\$ 80,00 ou em galões de 3,6 litros, que custam R\\$ 25,00.

# %%
import math

g = 80.00
l = 25.00

area = 0
litros_m2 = 6

area = input("Informe a área a ser pintada em m²: ")

if area.isnumeric():

    area = float(area)

    litros_tinta_g = area / 18 # Arredonda para cima a qtde
    litros_tinta_l = area / 3.6

    total_g = math.ceil(litros_tinta_g) * g
    total_l = math.ceil(litros_tinta_l) * l

    print("Você irá precisar de {:.0f} latas de tinta de 18 L e custará R$ {:.2f}".format(math.ceil(litros_tinta_g), total_g))

    print("Você irá precisar de {:.0f} latas de tinta de 3,6 L e custará R$ {:.2f}".format(math.ceil(litros_tinta_l), total_l))

else:

    print("Digite um valor válido para a área!")
# Out:
# Você irá precisar de 3 latas de tinta de 18 L e custará R$ 240.00
# Você irá precisar de 12 latas de tinta de 3,6 L e custará R$ 300.00

# %% [markdown]
# ##### Informe ao usuário as quantidades de tinta a serem compradas e os respectivos preços em 3 situações.
#
# Dica: lembre dos operadores // e % mostrados em exercícios anteriores<br>
# Dica1: numero // 10 vai te dar como resposta a parte inteira da divisão do número por 10.<br>
# Dica2: numero % 10 vai te dar o resto da divisão do número por 10.
#
# ##### 1. Comprar apenas latas de 18 litros: (apenas latas inteiras)

# %%
import math

print("Você irá precisar de {:.0f} latas de tinta de 18 L e custará R$ {:.2f}".format(math.ceil(litros_tinta_g), total_g))
# Out:
# Você irá precisar de 3 latas de tinta de 18 L e custará R$ 240.00

# %% [markdown]
# ##### 2. Comprar apenas galões de 3,6 litros: (apenas galoes inteiros)

# %%
import math
print("Você irá precisar de {:.0f} latas de tinta de 3,6 L e custará R$ {:.2f}".format(math.ceil(litros_tinta_l), total_l))
# Out:
# Você irá precisar de 12 latas de tinta de 3,6 L e custará R$ 300.00

# %% [markdown]
# ##### 3. Misturar latas e galões, de forma que o desperdício de tinta seja menor. Acrescente 10% de folga e sempre arredonde os valores para cima, isto é, considere latas cheias.

# %% [markdown]
# O custo da lata é 80/18 = 4,44 R\\$/L
#
# O custo do galão é 25/3,6 = 6,94 R\\$/L
#
# A lata é mais econômica, então todas as latas inteiras que pudermos usar devemos comprar em latas. Se ficar faltando alguma coisa para completar devemos avaliar se é melhor comprar latas ou galões. Exemplo:
#
# Se queremos comprar 90 litros. 5 latas dão exatamente 90 litros. Então devemos comprar tudo em latas.
#
# Se queremos comprar 95 litros. 5 latas dão exatamente 90 litros. Então devemos comprar pelo menos 5 latas e avaliar o que falta, se estes últimos 5 litros valem mais apenas em latas ou galões.
#
# Para os 5 litros faltantes precisamos de 2 galões que custam 50 reais no total. Ou de uma lata que custa 80 reais no total. Portanto, neste caso vale mais a pena usar 2 galões.
#
# Se queremos comprar 107 litros. 5 latas dão exatamente 90 litros. Então devemos comprar pelo menos 5 latas e avaliar o que falta, se estes últimos 5 litros valem mais apenas em latas ou galões.
#
# Para os 17 litros faltantes precisamos de 5 galões que custam 125 reais no total. Ou de uma lata que custa 80 reais no total. Portanto, neste caso vale mais a pena usar uma lata.
#
# 3 galões custam 75 reais, 4 galões custam 100 reais. Então, se for possível completar com até 3 galões escolhe-se galões. Qualquer quantidade maior que 3 galões, usa-se latas.
#
# Podemos ir ao exercício:

# %%
import math

def calcular_latas_e_galoes(area, rendimento_tinta):
    litros_tinta = math.ceil(area / rendimento_tinta)
    sobra = litros_tinta * 1.1  # adiciona uma margem de segurança de 10%
    galoes = int(sobra // 18)  # calcula o número de galões necessários (divisão inteira, descarta frações)
    tinta_faltante = sobra - 18 * galoes  # calcula a tinta que falta nos galões
    latas = math.ceil(tinta_faltante / 3.6)  # calcula o número de latas necessárias
    return galoes, latas

try:
    area = float(input("Digite a área em m²: "))
    rendimento_tinta = float(input("Qual a estimativa de rendimento do litro de tinta por m²: "))

    if area > 0 and rendimento_tinta > 0:
        if rendimento_tinta.is_integer():
            rendimento_tinta = int(rendimento_tinta)
    else:
        print("Os valores devem ser números positivos.")

    preco_galao = float(input("Digite o valor do galão de tinta de 18L: "))
    preco_lata = float(input("Digite o valor da lata de tinta de 3.6L: "))
    
    if preco_galao < 0 or preco_lata < 0:
        raise ValueError("O preço não pode ser negativo.")

    galoes, latas = calcular_latas_e_galoes(area, rendimento_tinta)
    
    custo_galoes = galoes * preco_galao
    custo_latas = latas * preco_lata
    preco_total = custo_galoes + custo_latas

    print(f'Para uma quantidade de {litros_tinta}L de tinta:')
    if galoes == 1:
        print(f' - É necessário {galoes} galão de 18L', end="")  # ao utilizar end="", a próxima impressão continuará na mesma linha, sem pular para a linha seguintel
    else:
        print(f' - São necessários {galoes} galões de 18L', end="")
    if latas == 1:
        print(f' e {latas} lata de 3.6L.')
    else:
        print(f' e {latas} latas de 3.6L.')
    print(f' - Custando R$ {preco_total:.2f} no total.')
    
except ValueError as e:
    print("Por favor, insira valores válidos para a área, rendimento da tinta e preços.")
# Out:
# Para uma quantidade de 50L de tinta:
#  - São necessários 3 galões de 18L e 1 lata de 3.6L.
#  - Custando R$ 280.00 no total.
